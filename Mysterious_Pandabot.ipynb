# %%
# 🐼 Загадочный Пандабот

import random

ответы_панды = [
    "Покой приходит к тому, кто ест бамбук 🍃",
    "Иногда молчание — лучший ответ 🧘‍♂️",
    "Даже панда может быть сильной, когда надо 🐾",
    "Спроси снова, но сначала съешь что-нибудь вкусное 🥢",
    "Каждое утро — это шанс стать лучше 🌅"
]

print("🐼 Привет! Я — Пандабот. Задай мне вопрос или напиши 'выход' для завершения.\n")

while True:
    вопрос = input("❓ Ты: ")
    if вопрос.lower() in ["выход", "quit", "exit"]:
        print("🐼 Панда говорит: До новых встреч! 🍃")
        break
    else:
        ответ = random.choice(ответы_панды)
        print("🧠 Панда: " + ответ + "\n")
# Out:
# 🐼 Привет! Я — Пандабот. Задай мне вопрос или напиши 'выход' для завершения.
#
# ❓ Ты: стоит ли учить Python?
# 🧠 Панда: Каждое утро — это шанс стать лучше 🌅
#
# ❓ Ты: Покой приходит к тому, кто ест бамбук 🍃
# 🧠 Панда: Даже панда может быть сильной, когда надо 🐾
#
# ❓ Ты: что делать дальше?
# 🧠 Панда: Даже панда может быть сильной, когда надо 🐾
#
# ❓ Ты: выход
# 🐼 Панда говорит: До новых встреч! 🍃
